# %%
import os
from dotenv import load_dotenv
from IPython.display import Image, display
from openai import OpenAI

# %%
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API kamu ada!")
# Out:
# API kamu ada!

# %%
message = "Halo Chatgpt, aku nanya kamu lewat API"

messages = [{"role": "user", "content": message}]

messages
# Out:
# [{'role': 'user', 'content': 'Halo Chatgpt, aku nanya kamu lewat API'}]

# %%
openai = OpenAI(api_key=api_key)

response = openai.chat.completions.create(model="gpt-5-mini", messages=messages)

response.choices[0].message.content
# Out:
# Halo! Senang kamu pakai API. Mau tanya apa spesifiknya? Contoh hal yang bisa kubantu:
# - Cara autentikasi / set API key
# - Contoh request (curl / Python / Node)
# - Pilih model (biaya vs kemampuan)
# - Streaming / handling respons panjang
# - Error handling / rate limits / debugging
# - Integrasi ke backend / frontend
#
# Kalau mau langsung contoh singkat (curl):
# curl -X POST https://api.openai.com/v1/chat/completions \
#   -H "Authorization: Bearer $OPENAI_API_KEY" \
#   -H "Content-Type: application/json" \
#   -d '{"model":"gpt-3.5-turbo","messages":[{"role":"user","content":"Halo, bantu aku buat ringkasan ini."}]}'
#
# Kirim detail soal yang kamu perlukan (kode yang sudah dicoba, error yang muncul, tujuan integrasi), supaya aku bisa bantu lebih spesifik.

# %%
print(response.choices[0].message.content)
# Out:
# Halo! Senang kamu pakai API. Mau tanya apa spesifiknya? Contoh hal yang bisa kubantu:
# - Cara autentikasi / set API key
# - Contoh request (curl / Python / Node)
# - Pilih model (biaya vs kemampuan)
# - Streaming / handling respons panjang
# - Error handling / rate limits / debugging
# - Integrasi ke backend / frontend
#
# Kalau mau langsung contoh singkat (curl):
# curl -X POST https://api.openai.com/v1/chat/completions \
#   -H "Authorization: Bearer $OPENAI_API_KEY" \
#   -H "Content-Type: application/json" \
#   -d '{"model":"gpt-3.5-turbo","messages":[{"role":"user","content":"Halo, bantu aku buat ringkasan ini."}]}'
#
# Kirim detail soal yang kamu perlukan (kode yang sudah dicoba, error yang muncul, tujuan integrasi), supaya aku bisa bantu lebih spesifik.
